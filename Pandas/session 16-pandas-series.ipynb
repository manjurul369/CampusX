# %%
import numpy as np
import pandas as pd

# %%
country = ['Bangladesh', 'Pakistan', 'Arab']
pd.Series(country)
# Out:
# 0    Bangladesh
# 1      Pakistan
# 2          Arab
# dtype: object

# %%
runs = [13,14,12,6,100]
pd.Series(runs)
# Out:
# 0     13
# 1     14
# 2     12
# 3      6
# 4    100
# dtype: int64

# %%
marks = [56,65,47,83]
subjects = ['Bangla', 'English', 'History', 'Maths']

pd.Series(marks, index=subjects,name='Students Marks')
# Out:
# Bangla     56
# English    65
# History    47
# Maths      83
# Name: Students Marks, dtype: int64

# %%
marks = {
    'Bangla': 56,
    'English': 65,
    'History': 47,
    'Maths': 83
}

mark_series = pd.Series(marks, name='Students Marks')
mark_series
# Out:
# Bangla     56
# English    65
# History    47
# Maths      83
# Name: Students Marks, dtype: int64

# %%
mark_series.size
# Out:
# 4

# %%
mark_series.dtype
# Out:
# dtype('int64')

# %%
mark_series.is_unique
# Out:
# True

# %%
mark_series.index
# Out:
# Index(['Bangla', 'English', 'History', 'Maths'], dtype='object')

# %%
mark_series.values
# Out:
# array([56, 65, 47, 83])

# %%
subs = pd.read_csv('/content/drive/MyDrive/Datasets/subs.csv').squeeze()

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('/content/drive/MyDrive/Datasets/kohli_ipl.csv', index_col='match_no').squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/drive/MyDrive/Datasets/bollywood.csv', index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs.head(3)
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40

# %%
subs.tail()
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
subs.sample(4)
# Out:
#      Subscribers gained
# 260                 138
# 90                   78
# 8                    44
# 222                 111

# %%
subs.value_counts()
# Out:
# Subscribers gained
# 105                   9
# 108                   6
# 88                    5
# 123                   5
# 72                    5
#                      ..
# 139                   1
# 137                   1
# 130                   1
# 129                   1
# 396                   1
# Name: count, Length: 180, dtype: int64

# %%
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
matches = pd.read_csv('/content/drive/MyDrive/Datasets/matches.csv')
matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
matches.sort_values(ascending=False, by='win_by_runs')
# Out:
#       id  season          city        date                        team1  \
# 43    44    2017         Delhi  2017-05-06               Mumbai Indians
# 619  620    2016     Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008     Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015     Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013     Bangalore  2013-04-23  Royal Challengers Bangalore
# ..   ...     ...           ...         ...                          ...
# 171  172    2009     Centurion  2009-05-22             Delhi Daredevils
# 172  173    2009  Johannesburg  2009-05-23          Chennai Super Kings
# 176  177    2010    Chandigarh  2010-03-13              Kings XI Punjab
# 177  178    2010       Kolkata  2010-03-14  Royal Challengers Bangalore
# 158  159    2009        Durban  2009-05-14          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
movies.sort_values()
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_index()
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# **Series Maths Methods**

# %%
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
subs.prod()
# Out:
# Subscribers gained    0
# dtype: int64

# %%
subs.min()
# Out:
# 33

# %%
subs.max()
# Out:
# Subscribers gained    396
# dtype: int64

# %%
subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
print(vk.median().values[0])
print(vk.mode().values[0][0])
print(subs.std().values[0])
print(vk.var().values[0])
# Out:
# 24.0
# 0
# 62.67502303725269
# 688.0024777222344

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
subs.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 365 entries, 0 to 364
# Series name: Subscribers gained
# Non-Null Count  Dtype
# --------------  -----
# 365 non-null    int64
# dtypes: int64(1)
# memory usage: 3.0 KB

# %% [markdown]
# **Series Indexing**

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[0]
# Out:
# 12

# %%
x[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-2fe32250a981> in <cell line: 0>()
# ----> 1 x[-1]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
print(movies['Awara Paagal Deewana'])
# Out:
# Akshay Kumar

# %%
vk[5:16]
# Out:
#           runs
# match_no
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# 13           3
# 14          11
# 15          50
# 16           2

# %%
vk[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
movies[::2]

# %%
vk[[1,5,10]]
# Out:
# match_no
# 1     1
# 5     1
# 10    3
# Name: runs, dtype: int64

# %% [markdown]
# **Series with Python Functionalitites**

# %%
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
list(vk)
# Out:
# [1,
#  23,
#  13,
#  12,
#  1,
#  9,
#  34,
#  0,
#  21,
#  3,
#  10,
#  38,
#  3,
#  11,
#  50,
#  2,
#  22,
#  19,
#  16,
#  15,
#  20,
#  38,
#  19,
#  24,
#  7,
#  2,
#  16,
#  17,
#  24,
#  38,
#  34,
#  42,
#  13,
#  58,
#  3,
#  14,
#  37,
#  9,
#  23,
#  12,
#  71,
#  35,
#  30,
#  56,
#  67,
#  27,
#  27,
#  39,
#  15,
#  11,
#  31,
#  70,
#  8,
#  35,
#  8,
#  6,
#  57,
#  22,
#  16,
#  4,
#  16,
#  18,
#  45,
#  9,
#  36,
#  9,
#  3,
#  73,
#  42,
#  24,
#  51,
#  35,
#  58,
#  65,
#  1,
#  11,
#  1,
#  32,
#  25,
#  57,
#  93,
#  99,
#  17,
#  14,
#  56,
#  49,
#  0,
#  31,
#  21,
#  4,
#  0,
#  35,
#  0,
#  4,
#  10,
#  27,
#  67,
#  38,
#  73,
#  13,
#  41,
#  18,
#  51,
#  62,
#  35,
#  1,
#  34,
#  48,
#  32,
#  82,
#  19,
#  44,
#  1,
#  12,
#  12,
#  75,
#  79,
#  33,
#  80,
#  100,
#  14,
#  52,
#  108,
#  20,
#  7,
#  109,
#  75,
#  113,
#  54,
#  0,
#  54,
#  62,
#  28,
#  64,
#  0,
#  10,
#  55,
#  20,
#  6,
#  5,
#  58,
#  31,
#  21,
#  57,
#  92,
#  30,
# ...

# %%
dict(movies)
# Out:
# {'Uri: The Surgical Strike': 'Vicky Kaushal',
#  'Battalion 609': 'Vicky Ahuja',
#  'The Accidental Prime Minister (film)': 'Anupam Kher',
#  'Why Cheat India': 'Emraan Hashmi',
#  'Evening Shadows': 'Mona Ambegaonkar',
#  'Soni (film)': 'Geetika Vidya Ohlyan',
#  'Fraud Saiyaan': 'Arshad Warsi',
#  'Bombairiya': 'Radhika Apte',
#  'Manikarnika: The Queen of Jhansi': 'Kangana Ranaut',
#  'Thackeray (film)': 'Nawazuddin Siddiqui',
#  'Amavas': 'Ali Asgar',
#  'Gully Boy': 'Ranveer Singh',
#  'Hum Chaar': 'Prit Kamani',
#  'Total Dhamaal': 'Ajay Devgn',
#  'Sonchiriya': 'Sushant Singh Rajput',
#  'Badla (2019 film)': 'Amitabh Bachchan',
#  'Mard Ko Dard Nahi Hota': 'Abhimanyu Dasani',
#  'Hamid (film)': 'Talha Arshad Reshi',
#  'Photograph (film)': 'Nawazuddin Siddiqui',
#  'Risknamaa': 'Garima Agarwal',
#  'Mere Pyare Prime Minister': 'Rasika Agashe',
#  '22 Yards': 'Barun Sobti',
#  'Kesari (film)': 'Akshay Kumar',
#  'Notebook (2019 film)': 'Zaheer Iqbal',
# ...

# %%
'Sikander Kher' in movies.values
# Out:
# True

# %%
for i in movies:
  print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
100 + vk
# Out:
# match_no
# 1      101
# 2      123
# 3      113
# 4      112
# 5      101
#       ...
# 211    100
# 212    120
# 213    173
# 214    125
# 215    107
# Name: runs, Length: 215, dtype: int64

# %%
vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
vk[vk >= 50].size
# Out:
# 50

# %%
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
import sys
sys.getsizeof(vk)
# Out:
# 3472

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 2182

# %%
vk[vk.between(51,99)].size
# Out:
# 43

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
droped = subs.drop_duplicates()
droped.size
# Out:
# 180

# %%
subs.size
# Out:
# 365

# %%
subs.duplicated().sum()
# Out:
# 185

# %%
temp = pd.Series([1,1,np.nan,3,5,6,72,np.nan,np.nan, 10])

# %%
temp
# Out:
# 0     1.0
# 1     1.0
# 2     NaN
# 3     3.0
# 4     5.0
# 5     6.0
# 6    72.0
# 7     NaN
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.isnull().sum()
# Out:
# 3

# %%
temp.dropna()
# Out:
# 0     1.0
# 1     1.0
# 3     3.0
# 4     5.0
# 5     6.0
# 6    72.0
# 9    10.0
# dtype: float64

# %%
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     1.0
# 2    14.0
# 3     3.0
# 4     5.0
# 5     6.0
# 6    72.0
# 7    14.0
# 8    14.0
# 9    10.0
# dtype: float64

# %%
vk[(vk == 49) | (vk == 99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk[vk.isin([49,99,0])]
# Out:
# match_no
# 8       0
# 82     99
# 86     49
# 87      0
# 91      0
# 93      0
# 130     0
# 135     0
# 206     0
# 207     0
# 211     0
# Name: runs, dtype: int64

# %%
subs.apply(lambda x: 'Good Day' if x > subs.mean() else 'Bad Day')
# Out:
# 0       Bad Day
# 1       Bad Day
# 2       Bad Day
# 3       Bad Day
# 4       Bad Day
#          ...
# 360    Good Day
# 361    Good Day
# 362    Good Day
# 363    Good Day
# 364    Good Day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
movies.apply(lambda x: x.split()[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-41369b41b373> in <cell line: 0>()
# ----> 1 movies.apply(lambda x: x.split()[1])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# ...

# %%
movies.apply(lambda x: x.split()[1] if len(x.split()) > 1 else np.nan)
# Out:
# movie
# Uri: The Surgical Strike                    Kaushal
# Battalion 609                                 Ahuja
# The Accidental Prime Minister (film)           Kher
# Why Cheat India                              Hashmi
# Evening Shadows                         Ambegaonkar
#                                            ...
# Hum Tumhare Hain Sanam                         Rukh
# Aankhen (2002 film)                        Bachchan
# Saathiya (film)                              Oberoi
# Company (film)                                Devgn
# Awara Paagal Deewana                          Kumar
# Name: lead, Length: 1500, dtype: object

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new = vk.head().copy()

# %%
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 40

# %%
new
# Out:
# match_no
# 1    40
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# # **If we use copy then main series won't changed**
